# %% [markdown]
# <a href="https://colab.research.google.com/github/Katsuraya3215/AI-study/blob/main/colab/appendix/3-recursion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##================================================
## このセルを最初に実行せよ---Run this cell first.
##================================================
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# !wget -P . https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# !wget -P fig https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Out:
# --2026-03-20 20:16:41--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/text-sample.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1779 (1.7K) [text/plain]
# Saving to: ‘./text-sample.txt’
#
# text-sample.txt     100%[===================>]   1.74K  --.-KB/s    in 0s
#
# 2026-03-20 20:16:41 (35.6 MB/s) - ‘./text-sample.txt’ saved [1779/1779]
#
# --2026-03-20 20:16:41--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27681 (27K) [application/octet-stream]
# Saving to: ‘./tokyo-temps.csv’
#
# tokyo-temps.csv     100%[===================>]  27.03K  --.-KB/s    in 0.001s
#
# 2026-03-20 20:16:42 (23.9 MB/s) - ‘./tokyo-temps.csv’ saved [27681/27681]
#
# --2026-03-20 20:16:42--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/small.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 45 [text/plain]
# Saving to: ‘./small.csv’
#
# small.csv           100%[===================>]      45  --.-KB/s    in 0s
#
# 2026-03-20 20:16:42 (775 KB/s) - ‘./small.csv’ saved [45/45]
#
# --2026-03-20 20:16:42--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/tokyo-july-temps.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1562 (1.5K) [text/plain]
# Saving to: ‘./tokyo-july-temps.csv’
#
# tokyo-july-temps.cs 100%[===================>]   1.53K  --.-KB/s    in 0s
#
# 2026-03-20 20:16:42 (14.5 MB/s) - ‘./tokyo-july-temps.csv’ saved [1562/1562]
#
# --2026-03-20 20:16:42--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/argsprint.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27 [text/plain]
# Saving to: ‘./argsprint.py’
#
# argsprint.py        100%[===================>]      27  --.-KB/s    in 0s
#
# 2026-03-20 20:16:42 (1.29 MB/s) - ‘./argsprint.py’ saved [27/27]
#
# --2026-03-20 20:16:42--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/B1S.xml
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 34029 (33K) [text/plain]
# Saving to: ‘./B1S.xml’
#
# B1S.xml             100%[===================>]  33.23K  --.-KB/s    in 0.002s
#
# 2026-03-20 20:16:42 (13.2 MB/s) - ‘./B1S.xml’ saved [34029/34029]
#
# --2026-03-20 20:16:43--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sample.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46 [text/plain]
# Saving to: ‘./sample.py’
#
# sample.py           100%[===================>]      46  --.-KB/s    in 0s
#
# 2026-03-20 20:16:43 (656 KB/s) - ‘./sample.py’ saved [46/46]
#
# --2026-03-20 20:16:43--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/sin.html
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8568 (8.4K) [text/plain]
# Saving to: ‘./sin.html’
#
# sin.html            100%[===================>]   8.37K  --.-KB/s    in 0s
#
# 2026-03-20 20:16:43 (60.8 MB/s) - ‘./sin.html’ saved [8568/8568]
#
# --2026-03-20 20:16:43--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/console_in_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39759 (39K) [image/png]
# Saving to: ‘fig/console_in_browser.png’
#
# console_in_browser. 100%[===================>]  38.83K  --.-KB/s    in 0s
#
# 2026-03-20 20:16:43 (130 MB/s) - ‘fig/console_in_browser.png’ saved [39759/39759]
#
# --2026-03-20 20:16:43--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71665 (70K) [image/png]
# Saving to: ‘fig/sample_py_win_1.png’
#
# sample_py_win_1.png 100%[===================>]  69.99K  --.-KB/s    in 0.01s
#
# 2026-03-20 20:16:43 (6.09 MB/s) - ‘fig/sample_py_win_1.png’ saved [71665/71665]
#
# --2026-03-20 20:16:43--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22452 (22K) [image/png]
# Saving to: ‘fig/sample_py_win_3.png’
#
# sample_py_win_3.png 100%[===================>]  21.93K  --.-KB/s    in 0s
#
# 2026-03-20 20:16:44 (104 MB/s) - ‘fig/sample_py_win_3.png’ saved [22452/22452]
#
# --2026-03-20 20:16:44--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11249 (11K) [image/png]
# Saving to: ‘fig/sample_py_win_2.png’
#
# sample_py_win_2.png 100%[===================>]  10.99K  --.-KB/s    in 0.003s
#
# 2026-03-20 20:16:44 (3.89 MB/s) - ‘fig/sample_py_win_2.png’ saved [11249/11249]
#
# --2026-03-20 20:16:44--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 22815 (22K) [image/png]
# Saving to: ‘fig/py_open_2.png’
#
# py_open_2.png       100%[===================>]  22.28K  --.-KB/s    in 0.001s
#
# 2026-03-20 20:16:44 (21.9 MB/s) - ‘fig/py_open_2.png’ saved [22815/22815]
#
# --2026-03-20 20:16:44--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_open_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36596 (36K) [image/png]
# Saving to: ‘fig/py_open_1.png’
#
# py_open_1.png       100%[===================>]  35.74K  --.-KB/s    in 0.003s
#
# 2026-03-20 20:16:44 (13.9 MB/s) - ‘fig/py_open_1.png’ saved [36596/36596]
#
# --2026-03-20 20:16:44--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 7800 (7.6K) [image/png]
# Saving to: ‘fig/sample_py_mac_2.png’
#
# sample_py_mac_2.png 100%[===================>]   7.62K  --.-KB/s    in 0s
#
# 2026-03-20 20:16:45 (51.8 MB/s) - ‘fig/sample_py_mac_2.png’ saved [7800/7800]
#
# --2026-03-20 20:16:45--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 21366 (21K) [image/png]
# Saving to: ‘fig/sample_py_mac_3.png’
#
# sample_py_mac_3.png 100%[===================>]  20.87K  --.-KB/s    in 0.001s
#
# 2026-03-20 20:16:45 (15.0 MB/s) - ‘fig/sample_py_mac_3.png’ saved [21366/21366]
#
# --2026-03-20 20:16:45--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54233 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_1.png’
#
# sample_py_win2_1.pn 100%[===================>]  52.96K  --.-KB/s    in 0.009s
#
# 2026-03-20 20:16:45 (5.45 MB/s) - ‘fig/sample_py_win2_1.png’ saved [54233/54233]
#
# --2026-03-20 20:16:45--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_3.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 10214 (10.0K) [image/png]
# Saving to: ‘fig/sample_py_win2_3.png’
#
# sample_py_win2_3.pn 100%[===================>]   9.97K  --.-KB/s    in 0.001s
#
# 2026-03-20 20:16:45 (14.1 MB/s) - ‘fig/sample_py_win2_3.png’ saved [10214/10214]
#
# --2026-03-20 20:16:45--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_mac_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238677 (233K) [image/png]
# Saving to: ‘fig/sample_py_mac_1.png’
#
# sample_py_mac_1.png 100%[===================>] 233.08K  --.-KB/s    in 0.02s
#
# 2026-03-20 20:16:45 (9.93 MB/s) - ‘fig/sample_py_mac_1.png’ saved [238677/238677]
#
# --2026-03-20 20:16:46--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_win2_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54719 (53K) [image/png]
# Saving to: ‘fig/sample_py_win2_2.png’
#
# sample_py_win2_2.pn 100%[===================>]  53.44K  --.-KB/s    in 0.009s
#
# 2026-03-20 20:16:46 (5.62 MB/s) - ‘fig/sample_py_win2_2.png’ saved [54719/54719]
#
# --2026-03-20 20:16:46--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/argsprint.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17101 (17K) [image/png]
# Saving to: ‘fig/argsprint.png’
#
# argsprint.png       100%[===================>]  16.70K  --.-KB/s    in 0.001s
#
# 2026-03-20 20:16:46 (27.0 MB/s) - ‘fig/argsprint.png’ saved [17101/17101]
#
# --2026-03-20 20:16:46--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/terminal_in_menu.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 12461 (12K) [image/png]
# Saving to: ‘fig/terminal_in_menu.png’
#
# terminal_in_menu.pn 100%[===================>]  12.17K  --.-KB/s    in 0.001s
#
# 2026-03-20 20:16:46 (20.2 MB/s) - ‘fig/terminal_in_menu.png’ saved [12461/12461]
#
# --2026-03-20 20:16:46--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/sample_py_browser.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 58231 (57K) [image/png]
# Saving to: ‘fig/sample_py_browser.png’
#
# sample_py_browser.p 100%[===================>]  56.87K  --.-KB/s    in 0.008s
#
# 2026-03-20 20:16:46 (6.86 MB/s) - ‘fig/sample_py_browser.png’ saved [58231/58231]
#
# --2026-03-20 20:16:46--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_1.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 27636 (27K) [image/png]
# Saving to: ‘fig/py_conv_1.png’
#
# py_conv_1.png       100%[===================>]  26.99K  --.-KB/s    in 0.002s
#
# 2026-03-20 20:16:47 (17.1 MB/s) - ‘fig/py_conv_1.png’ saved [27636/27636]
#
# --2026-03-20 20:16:47--  https://raw.githubusercontent.com/utokyo-ipp/utokyo-ipp.github.io/master/colab/appendix/fig/py_conv_2.png
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 59488 (58K) [image/png]
# Saving to: ‘fig/py_conv_2.png’
#
# py_conv_2.png       100%[===================>]  58.09K  --.-KB/s    in 0.009s
#
# 2026-03-20 20:16:47 (6.51 MB/s) - ‘fig/py_conv_2.png’ saved [59488/59488]

# %% [markdown]
# # ▲再帰
# **再帰**について説明します。
#
# 関数の**再帰呼び出し**とは、定義しようとしている関数を、その定義の中で呼び出すことです。
# 定義の中で直接呼び出す場合に限らず、他の関数を経由して間接的に呼び出す場合も、再帰呼び出しに含まれます。
# 再帰呼び出しを行う関数を、**再帰関数**といいます。
#
# 再帰関数は、**分割統治**アルゴリズムの記述に適しています。
# 分割統治とは、問題を容易に解ける小さな粒度まで分割していき、
# 個々の小さな問題を解いて、その部分解を合成することで問題全体を解くような方法を指します。
# 分割統治の考え方は、関数型プログラミングにおいてもよく用いられます。
# 再帰関数による分割統治の典型的な形は、次の通りです。
#
# ```Python
# def recursive_function(...):
#     if 問題粒度の判定:
#         再帰呼び出しを含まない基本処理
#     else:
#         再帰呼び出しを含む処理（問題の分割や部分解の合成を行う）
# ```

# %% [markdown]
# 以下で、再帰関数を使った処理の例をいくつか見ていきましょう。

# %% [markdown]
# ## 再帰関数の例：接頭辞リストと接尾辞リスト

# %%
# 入力の文字列の接頭辞リストを返す関数prefixes
def prefixes(s):
    if s == '':
        return []
    else:
        return [s] + prefixes(s[:-1])

prefixes('aabcc')
# Out:
# ['aabcc', 'aabc', 'aab', 'aa', 'a']

# %% [markdown]
# ※関数自体を返すので、for文的に繰り返す構造
#
# ※＋によって返された文字列は、同じリストの中にはいる。["a"],["aa"]...のようにはならないので注意
#
# ※[:-1]は、スライスが終わりの1つ手前までの指定なので、1つずつ減っていく表現になる。

# %%
# 入力の文字列の接尾辞リストを返す関数suffixes
def suffixes(s):
    if s == '':
        return []
    else:
        return [s] + suffixes(s[1:])

suffixes('aabcc')
# Out:
# ['aabcc', 'abcc', 'bcc', 'cc', 'c']

# %% [markdown]
# ## 再帰関数の例：べき乗の計算

# %%
# 入力の底baseと冪指数exptからべき乗を計算する関数power
def power(base, expt):
    if expt == 0:
        # exptが0ならば1を返す
        return 1
    else:
        # exptを1つずつ減らしながらpowerに渡し、再帰的にべき乗を計算
        # (2*(2*(2*....*1)))
        return base * power(base, expt - 1)

power(2,10)
# Out:
# 1024

# %% [markdown]
# 一般に、再帰処理は、繰り返し処理としても書くことができます。

# %%
# べき乗の計算を繰り返し処理で行った例
def power(base, expt):
    e = 1
    for i in range(expt):
        e *= base
    return e

power(2,10)
# Out:
# 1024

# %% [markdown]
# 単純な処理においては、繰り返しの方が効率的に計算できることが多いですが、
# 特に複雑な処理になってくると、再帰的に定義した方が読みやすいコードで効率的なアルゴリズムを記述できることもあります。
# たとえば、次に示すべき乗計算は、上記よりも高速なアルゴリズムですが、計算の見通しは明快です。

# %%
# べき乗を計算する高速なアルゴリズム
def power(base, expt):
    if expt == 0:
        return 1
    elif expt % 2 == 0:
        return power(base * base, expt // 2) # x**(2m) == (x*x)**m
    else:
        return base * power(base, expt - 1)

power(2,10)
# Out:
# 1024

# %% [markdown]
# ## 再帰関数の例：マージソート
#
# マージソートは、典型的な分割統治アルゴリズムで、以下のように再帰関数で実装することができます。

# %%
# マージソートを行い、比較回数 n を返す
def merge_sort_rec(data, l, r, work):
    n = 0
    if r - l <= 1:
        return n
    m = l + (r - l) // 2
    n1 = merge_sort_rec(data, l, m, work)
    n2 = merge_sort_rec(data, m, r, work)
    i1 = l
    i2 = m
    for i in range(l, r):
        from1 = False
        if i2 >= r:
            from1 = True
        elif i1 < m:
            n = n + 1
            if data[i1] <= data[i2]:
                from1 = True
        if from1:
            work[i] = data[i1]
            i1 = i1 + 1
        else:
            work[i] = data[i2]
            i2 = i2 + 1
    for i in range(l, r):
        data[i] = work[i]
    return n1 + n2 + n

def merge_sort(data):
    return merge_sort_rec(data, 0, len(data), [0]*len(data))

# %% [markdown]
# `merge_sort` は、与えられた配列をインプレースでソートするとともに、比較の回数を返します。
# `merge_sort` は、再帰関数 `merge_sort_rec` を呼び出します。
#
# `merge_sort_rec(data, l, r, work)` は、配列 `data` のインデックスが `l` 以上で `r` より小さいところをソートします。
#
# - 要素が1つかないときは何もしません。
# - そうでなければ、`l` から　`r` までの要素を半分にしてそれぞれを再帰的にソートします。
# - その結果を作業用の配列 `work` に順序を保ちながらコピーします。この操作はマージ（併合）と呼ばれます。
# - 最後に、`work` から `data` に要素を戻します。
#
# `merge_sort_rec` は自分自身を2回呼び出していますので、繰り返しでは容易には実装できません。

# %%
import random
a = [random.randint(1,10000) for i in range(100)]
merge_sort(a)
# Out:
# 546

# %%
a
# Out:
# [76,
#  80,
#  96,
#  101,
#  136,
#  232,
#  279,
#  364,
#  606,
#  900,
#  1007,
#  1064,
#  1075,
#  1076,
#  1262,
#  1423,
#  1517,
#  2005,
#  2060,
#  2140,
#  2250,
#  2328,
#  2338,
#  2480,
#  2551,
#  2695,
#  3016,
#  3087,
#  3095,
#  3141,
#  3180,
#  3236,
#  3307,
#  3334,
#  3575,
#  3613,
#  3729,
#  3730,
#  3742,
#  4056,
#  4114,
#  4144,
#  4194,
#  4329,
#  4364,
#  4421,
#  4533,
#  4681,
#  4778,
#  4981,
#  5156,
#  5451,
#  5537,
#  5541,
#  5642,
#  5703,
#  5710,
#  5794,
#  5903,
#  6080,
#  6156,
#  6156,
#  6185,
#  6259,
#  6356,
#  6381,
#  6404,
#  6457,
#  6517,
#  6779,
#  6815,
#  6966,
#  7120,
#  7189,
#  7325,
#  7363,
#  7415,
#  7434,
#  7653,
#  7659,
#  7743,
#  7772,
#  7855,
#  7859,
#  7897,
#  7924,
#  8015,
#  8507,
#  8597,
#  8599,
#  8648,
#  8720,
#  8991,
#  9153,
#  9308,
#  9323,
#  9476,
#  9680,
#  9696,
#  9727]
